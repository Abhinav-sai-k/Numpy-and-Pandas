# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav-sai-k/Numpy-and-Pandas/blob/main/openpyxl_for_excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import openpyxl
import pandas as pd

# %%
workbook = openpyxl.Workbook()
sheet  = workbook.active

data  = [
  ["employeeId", "name", "jobTitle", "department", "salary", "hireDate"],
  ["E001", "John Smith", "Software Engineer", "Engineering", 85000, "2022-03-15"],
  ["E002", "Maria Gonzalez", "Marketing Manager", "Marketing", 95000, "2021-07-01"],
  ["E003", "David Lee", "Data Analyst", "Analytics", 70000, "2023-01-10"],
  ["E004", "Sarah Patel", "HR Specialist", "Human Resources", 65000, "2020-11-22"],
  ["E005", "Michael Brown", "Sales Representative", "Sales", 60000, "2022-09-05"],
  ["E006", "Emily Davis", "Product Manager", "Product", 110000, "2019-04-18"],
  ["E007", "Alex Kim", "IT Support", "IT", 55000, "2023-06-30"],
  ["E008", "Olivia White", "Graphic Designer", "Creative", 62000, "2021-12-12"]
]

# %%
for i in data:
  sheet.append(i)
  print(i)
  print()
# Out:
# ['employeeId', 'name', 'jobTitle', 'department', 'salary', 'hireDate']
#
# ['E001', 'John Smith', 'Software Engineer', 'Engineering', 85000, '2022-03-15']
#
# ['E002', 'Maria Gonzalez', 'Marketing Manager', 'Marketing', 95000, '2021-07-01']
#
# ['E003', 'David Lee', 'Data Analyst', 'Analytics', 70000, '2023-01-10']
#
# ['E004', 'Sarah Patel', 'HR Specialist', 'Human Resources', 65000, '2020-11-22']
#
# ['E005', 'Michael Brown', 'Sales Representative', 'Sales', 60000, '2022-09-05']
#
# ['E006', 'Emily Davis', 'Product Manager', 'Product', 110000, '2019-04-18']
#
# ['E007', 'Alex Kim', 'IT Support', 'IT', 55000, '2023-06-30']
#
# ['E008', 'Olivia White', 'Graphic Designer', 'Creative', 62000, '2021-12-12']

# %%
# save this excel file!
#This file is saved in collab storage
workbook.save(filename="example_excel.csv")

# %%
#if file is stored in current working directory, we can fetch current path using!
import os
os.getcwd()
# Out:
# '/content'

# %%
# If you want to read excel using pandas
df =  pd.read_excel(r"/content/example_excel.csv")
df
# Out:
#   employeeId            name              jobTitle       department  salary  \
# 0       E001      John Smith     Software Engineer      Engineering   85000
# 1       E002  Maria Gonzalez     Marketing Manager        Marketing   95000
# 2       E003       David Lee          Data Analyst        Analytics   70000
# 3       E004     Sarah Patel         HR Specialist  Human Resources   65000
# 4       E005   Michael Brown  Sales Representative            Sales   60000
# 5       E006     Emily Davis       Product Manager          Product  110000
# 6       E007        Alex Kim            IT Support               IT   55000
# 7       E008    Olivia White      Graphic Designer         Creative   62000
#
#      hireDate
# 0  2022-03-15
# 1  2021-07-01
# 2  2023-01-10
# 3  2020-11-22
# 4  2022-09-05
# 5  2019-04-18
# 6  2023-06-30
# 7  2021-12-12

# %%
df.shape
# Out:
# (8, 6)

# %%
df.size
# Out:
# 48

# %%
df.columns
# Out:
# Index(['employeeId', 'name', 'jobTitle', 'department', 'salary', 'hireDate'], dtype='object')

# %%
df[1:3]
# Out:
#   employeeId            name           jobTitle department  salary    hireDate
# 1       E002  Maria Gonzalez  Marketing Manager  Marketing   95000  2021-07-01
# 2       E003       David Lee       Data Analyst  Analytics   70000  2023-01-10

# %%
df[['employeeId','name','department']]
# Out:
#   employeeId            name       department
# 0       E001      John Smith      Engineering
# 1       E002  Maria Gonzalez        Marketing
# 2       E003       David Lee        Analytics
# 3       E004     Sarah Patel  Human Resources
# 4       E005   Michael Brown            Sales
# 5       E006     Emily Davis          Product
# 6       E007        Alex Kim               IT
# 7       E008    Olivia White         Creative

# %%
# some graphs using seaborn
import seaborn as sns

sns.barplot(x="department", y="salary", data=df)
# Out:
# <Axes: xlabel='department', ylabel='salary'>
