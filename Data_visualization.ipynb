# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav-sai-k/Numpy-and-Pandas/blob/main/Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"/content/Movie-Rating.csv")
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
np.__version__

'''
__name__(main function)
__init__(constructor)
'''
# Out:
# '\n__name__(main function)\n__init__(constructor)\n'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df.shape
# Out:
# (559, 6)

# %%
df.size #(559*6)
# Out:
# 3354

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %% [markdown]
# #Rename a column in df

# %%
df.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillions', 'Year']

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
display(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB
# None
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# ...

# %%
df.Year.astype('category')
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
df.Genre.astype('category')
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %% [markdown]
# #Visualizations

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

#All plot should be inside line
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot( data=df,x='CriticRating',y='AudienceRating')

# %%
j = sns.jointplot( data=df,x='CriticRating',y='AudienceRating',kind='hex')

# %%
j = sns.jointplot( data=df,x='CriticRating',y='AudienceRating',kind='kde')

# %%
j = sns.jointplot( data=df,x='CriticRating',y='AudienceRating',kind='reg')

# %%
sns.distplot(df.AudienceRating)
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
sns.distplot(df.CriticRating)
# Out:
# <Axes: xlabel='CriticRating', ylabel='Density'>

# %%
sns.displot( df.AudienceRating)

# %%
# If you want to change grid
# sns.set_style("darkgrid")

# %%
sns.displot(df.CriticRating)

# %%
# sns.set_style('darkgrid')

# %%
sns.histplot(df.AudienceRating,bins=30)
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Count'>

# %%
sns.histplot(df.CriticRating,bins=30)
# Out:
# <Axes: xlabel='CriticRating', ylabel='Count'>

# %%
sns.histplot(df.BudgetMillions,bins=30)
# Out:
# <Axes: xlabel='BudgetMillions', ylabel='Count'>

# %% [markdown]
# Most movies are low budget
# High budget movies are very limited in frequency

# %%
sns.lmplot(data=df,x='CriticRating',y='AudienceRating',fit_reg=True)

# %%
sns.lmplot(data=df,x='CriticRating',y='AudienceRating',fit_reg=True,hue="Genre")

# %% [markdown]
# # subplots

# %%
 ax = plt.subplots(3,3,figsize=(10,8))

# %%
sns.boxplot(data=df,y='AudienceRating',x='Genre')
# Out:
# <Axes: xlabel='Genre', ylabel='AudienceRating'>

# %%
sns.boxplot(data=df,y='AudienceRating',x='CriticRating')
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
sns.boxplot(data=df,y='AudienceRating',x='Genre',hue='Year')
# Out:
# <Axes: xlabel='Genre', ylabel='AudienceRating'>

# %%
sns.boxplot(data=df[df.Genre=='Drama'],y='AudienceRating',x='Year')
# Out:
# <Axes: xlabel='Year', ylabel='AudienceRating'>

# %% [markdown]
# # what does the plot say?
# 2007 and 2011 dramas are highly regarded

# %% [markdown]
# #Facet Grid
#
# It visualize multiple graphs

# %%
df.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
sns.FacetGrid(data=df,row='Genre',col='Year',hue='Genre')

# %%
fplot = sns.FacetGrid(data=df,row='Genre',col='Year',hue='Genre') #(Gives all possible subplots)
fplot= fplot.map(plt.scatter,'AudienceRating','CriticRating')  #(what to do in that subplot? pass plottype as functioncall and x,y arguments)

# %%
fplot = sns.FacetGrid(data=df,row='Genre',col='Year',hue='Genre') #(Gives all possible subplots)

fplot.map(sns.histplot,'BudgetMillions')

# %%
df
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...
